# %% [markdown]
# # EDA — Netflix Customer Intelligence
#
# This notebook documents the exploratory analysis. The full reproducible pipeline lives in `src/eda/eda_plots.py` (30 figures across the 7 PRD themes) and `src/features/build_features.py` (customer-level feature table).

# %%
# Regenerate all EDA figures
# %run ../src/eda/eda_plots.py

# %%
# Build the customer-level feature table
# %run ../src/features/build_features.py
